# %% [markdown]
# [download this notebook here](https://github.com/HumanCompatibleAI/imitation/blob/master/docs/tutorials/4_train_airl.ipynb)
# # Train an Agent using Adversarial Inverse Reinforcement Learning

# %% [markdown]
# As usual, we first need an expert. Again, we download one from the HuggingFace model hub for convenience.
#
# Note that we now use a variant of the CartPole environment from the seals package, which has fixed episode durations. Read more about why we do this [here](https://imitation.readthedocs.io/en/latest/getting-started/variable-horizon.html).

# %%
import numpy as np
from imitation.policies.serialize import load_policy
from imitation.util.util import make_vec_env
from imitation.data.wrappers import RolloutInfoWrapper

SEED = 42

FAST = False

if FAST:
    N_RL_TRAIN_STEPS = 100_000
else:
    N_RL_TRAIN_STEPS = 2_000_000

venv = make_vec_env(
    "seals:seals/CartPole-v0",
    rng=np.random.default_rng(SEED),
    n_envs=8,
    post_wrappers=[
        lambda env, _: RolloutInfoWrapper(env)
    ],  # needed for computing rollouts later
)
expert = load_policy(
    "ppo-huggingface",
    organization="HumanCompatibleAI",
    env_name="seals/CartPole-v0",
    venv=venv,
)
# Out:
# /home/chris/miniconda3/envs/env_lift/lib/python3.11/site-packages/stable_baselines3/common/save_util.py:166: UserWarning: Could not deserialize object learning_rate. Consider using `custom_objects` argument to replace this object.
# Exception: code() argument 13 must be str, not int
#   warnings.warn(
# /home/chris/miniconda3/envs/env_lift/lib/python3.11/site-packages/stable_baselines3/common/save_util.py:166: UserWarning: Could not deserialize object clip_range. Consider using `custom_objects` argument to replace this object.
# Exception: code() argument 13 must be str, not int
#   warnings.warn(
# /home/chris/miniconda3/envs/env_lift/lib/python3.11/site-packages/stable_baselines3/common/save_util.py:166: UserWarning: Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: code() argument 13 must be str, not int
#   warnings.warn(

# %% [markdown]
# Visualization of Expert Policy:

# %%
import gymnasium as gym
import os
from IPython.display import display, clear_output
import matplotlib.pyplot as plt

render_mode = "human" if os.environ.get('DISPLAY') else "rgb_array"
env = gym.make("seals:seals/CartPole-v0", render_mode=render_mode)

# Gymnasium returns (obs, info) from reset(); unpack so `obs` is the raw observation
obs, info = env.reset()

for _ in range(1000):
    # Pass only the observation (not the (obs, info) tuple) to the SB3 policy
    action, _ = expert.predict(obs, deterministic=True)

    # Gymnasium step returns (obs, reward, terminated, truncated, info)
    obs, rew, terminated, truncated, info = env.step(action)

    # Render depending on mode. For `rgb_array` we collect and display frames inside the notebook.
    if render_mode == "rgb_array":
        frame = env.render()
        # display every 10 frames to avoid excessive output
        if (_ % 10) == 0:
            clear_output(wait=True)
            plt.imshow(frame)
            plt.axis('off')
            display(plt.gcf())
    else:
        env.render()   # opens a window (when DISPLAY is available)

    # episode end when either terminated or truncated
    if terminated or truncated:
        obs, info = env.reset()
        # if running in rgb_array mode, break after one episode to show the frames
        if render_mode == "rgb_array":
            break

env.close()
# Out:
# /home/chris/miniconda3/envs/env_lift/lib/python3.11/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %% [markdown]
# We generate some expert trajectories, that the discriminator needs to distinguish from the learner's trajectories.

# %%
from imitation.data import rollout

rollouts = rollout.rollout(
    expert,
    venv,
    rollout.make_sample_until(min_timesteps=None, min_episodes=60),
    rng=np.random.default_rng(SEED),
)

# %% [markdown]
# Visualization of sampled Expert Trajectories:

# %%
# Exact playback from saved observations (CartPole-specific).
# This will set the environment internal state from each saved observation and render it,
# avoiding stepping actions so visuals match the saved rollouts exactly where possible.
import os
import time
import numpy as np
import gymnasium as gym
from IPython.display import display, clear_output
import matplotlib.pyplot as plt

# Ensure rollouts exist
try:
    trajs = rollouts if hasattr(rollouts, '__len__') else [rollouts]
except NameError:
    raise RuntimeError('`rollouts` not found — run the rollout generation cell first')

render_mode = "human" if os.environ.get('DISPLAY') else "rgb_array"
n_play = min(5, len(trajs))
print(f'Playing {n_play} sampled expert rollouts exactly from saved observations (render_mode={render_mode})')

for i in range(n_play):
    traj = trajs[i]
    # Make a fresh env for each trajectory
    env = gym.make("seals:seals/CartPole-v0", render_mode=render_mode)
    env.reset()

    # Check if we can set internal state directly (CartPole exposes `env.unwrapped.state`).
    can_set_state = hasattr(env, 'unwrapped') and hasattr(env.unwrapped, 'state')
    if not can_set_state:
        print('Warning: env does not support setting internal state; exact playback not possible. Falling back to stepping actions.')

    if can_set_state:
        # traj.obs is length T+1; render each saved observation in sequence
        for t, obs_state in enumerate(traj.obs):
            st = np.asarray(obs_state).copy()
            try:
                env.unwrapped.state = st
            except Exception as e:
                print('Could not assign env.unwrapped.state, falling back to stepping. Error:', e)
                can_set_state = False
                break
            if render_mode == 'rgb_array':
                frame = env.render()
                clear_output(wait=True)
                plt.imshow(frame)
                plt.axis('off')
                display(plt.gcf())
            else:
                env.render()
            # small delay so notebook updates are visible
            time.sleep(0.02)

    if not can_set_state:
        # Fallback: step the saved actions into the env (may diverge from original)
        env.reset()
        for act in traj.acts:
            a = np.asarray(act)
            if a.shape == ():
                a = a.item()
            obs, rew, terminated, truncated, info = env.step(a)
            if render_mode == 'rgb_array':
                frame = env.render()
                clear_output(wait=True)
                plt.imshow(frame)
                plt.axis('off')
                display(plt.gcf())
            else:
                env.render()
            if terminated or truncated:
                break

    env.close()
    # brief pause between trajectories
    if render_mode == 'rgb_array':
        time.sleep(0.5)

print('Done playing exact rollouts')
# Out:
# Playing 5 sampled expert rollouts exactly from saved observations (render_mode=human)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 51
#      49             env.render()
#      50         # small delay so notebook updates are visible
# ---> 51         time.sleep(0.02)
#      53 if not can_set_state:
#      54     # Fallback: step the saved actions into the env (may diverge from original)
#      55     env.reset()
#
# KeyboardInterrupt:

# %% [markdown]
# Now we are ready to set up our AIRL trainer.
# Note, that the `reward_net` is actually the network of the discriminator.
# We evaluate the learner before and after training so we can see if it made any progress.

# %% [markdown]
# Initialization of Learner policy (AIRL Generator):

# %%
from imitation.algorithms.adversarial.airl import AIRL
from imitation.rewards.reward_nets import BasicShapedRewardNet
from imitation.util.networks import RunningNorm
from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.evaluation import evaluate_policy


learner = PPO(
    env=venv,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0005,
    gamma=0.95,
    clip_range=0.1,
    vf_coef=0.1,
    n_epochs=5,
    seed=SEED,
)

# %% [markdown]
# Visualization of untrained Learner Policy (AIRL Generator):

# %%
render_mode = "human" if os.environ.get('DISPLAY') else "rgb_array"
env = gym.make("seals:seals/CartPole-v0", render_mode=render_mode)

# Gymnasium returns (obs, info) from reset(); unpack so `obs` is the raw observation
obs, info = env.reset()

for _ in range(1000):
    # Pass only the observation (not the (obs, info) tuple) to the SB3 policy
    action, _ = learner.predict(obs, deterministic=True)

    # Gymnasium step returns (obs, reward, terminated, truncated, info)
    obs, rew, terminated, truncated, info = env.step(action)

    # Render depending on mode. For `rgb_array` we collect and display frames inside the notebook.
    if render_mode == "rgb_array":
        frame = env.render()
        # display every 10 frames to avoid excessive output
        if (_ % 10) == 0:
            clear_output(wait=True)
            plt.imshow(frame)
            plt.axis('off')
            display(plt.gcf())
    else:
        env.render()   # opens a window (when DISPLAY is available)

    # episode end when either terminated or truncated
    if terminated or truncated:
        obs, info = env.reset()
        # if running in rgb_array mode, break after one episode to show the frames
        if render_mode == "rgb_array":
            break

env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 24
#      22         display(plt.gcf())
#      23 else:
# ---> 24     env.render()   # opens a window (when DISPLAY is available)
#      26 # episode end when either terminated or truncated
#      27 if terminated or truncated:
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/gymnasium/core.py:471, in Wrapper.render(self)
#     469 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     470     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 471     return self.env.render()
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/gymnasium/wrappers/order_enforcing.py:70, in OrderEnforcing.render(self, *args, **kwargs)
#      65 if not self._disable_render_order_enforcing and not self._has_reset:
#      66     raise ResetNeeded(
#      67         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      68         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      69     )
# ---> 70 return self.env.render(*args, **kwargs)
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/gymnasium/wrappers/env_checker.py:67, in PassiveEnvChecker.render(self, *args, **kwargs)
#      65     return env_render_passive_checker(self.env, *args, **kwargs)
#      66 else:
# ---> 67     return self.env.render(*args, **kwargs)
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/gymnasium/envs/classic_control/cartpole.py:302, in CartPoleEnv.render(self)
#     300 if self.render_mode == "human":
#     301     pygame.event.pump()
# --> 302     self.clock.tick(self.metadata["render_fps"])
#     303     pygame.display.flip()
#     305 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:

# %% [markdown]
# AIRL Training:

# %%
reward_net = BasicShapedRewardNet(
    observation_space=venv.observation_space,
    action_space=venv.action_space,
    normalize_input_layer=RunningNorm,
)
airl_trainer = AIRL(
    demonstrations=rollouts,
    demo_batch_size=2048,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=16,
    venv=venv,
    gen_algo=learner,
    reward_net=reward_net,
)

venv.seed(SEED)
learner_rewards_before_training, _ = evaluate_policy(
    learner, venv, 100, return_episode_rewards=True
)
airl_trainer.train(N_RL_TRAIN_STEPS)
venv.seed(SEED)
learner_rewards_after_training, _ = evaluate_policy(
    learner, venv, 100, return_episode_rewards=True
)
# Out:
# round:   0%|          | 0/122 [00:00<?, ?it/s]
# ------------------------------------------
# | raw/                        |          |
# |    gen/rollout/ep_len_mean  | 500      |
# |    gen/rollout/ep_rew_mean  | 34.4     |
# |    gen/time/fps             | 7603     |
# |    gen/time/iterations      | 1        |
# |    gen/time/time_elapsed    | 2        |
# |    gen/time/total_timesteps | 16384    |
# ------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.505    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.0103   |
# |    disc/disc_entropy                | 0.663    |
# |    disc/disc_loss                   | 0.74     |
# |    disc/disc_proportion_expert_pred | 0.995    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.505    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.0103   |
# |    disc/disc_entropy                | 0.665    |
# |    disc/disc_loss                   | 0.733    |
# |    disc/disc_proportion_expert_pred | 0.995    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.506    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.0122   |
# |    disc/disc_entropy                | 0.666    |
# |    disc/disc_loss                   | 0.729    |
# |    disc/disc_proportion_expert_pred | 0.994    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.506    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.0127   |
# |    disc/disc_entropy                | 0.667    |
# |    disc/disc_loss                   | 0.728    |
# |    disc/disc_proportion_expert_pred | 0.994    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.507    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.0132   |
# |    disc/disc_entropy                | 0.668    |
# |    disc/disc_loss                   | 0.723    |
# |    disc/disc_proportion_expert_pred | 0.993    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.508    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.0156   |
# |    disc/disc_entropy                | 0.669    |
# |    disc/disc_loss                   | 0.719    |
# |    disc/disc_proportion_expert_pred | 0.992    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.51     |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.0205   |
# |    disc/disc_entropy                | 0.671    |
# |    disc/disc_loss                   | 0.716    |
# |    disc/disc_proportion_expert_pred | 0.99     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.517    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.0337   |
# |    disc/disc_entropy                | 0.672    |
# |    disc/disc_loss                   | 0.708    |
# |    disc/disc_proportion_expert_pred | 0.983    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.519    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.0371   |
# |    disc/disc_entropy                | 0.673    |
# |    disc/disc_loss                   | 0.709    |
# |    disc/disc_proportion_expert_pred | 0.981    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.525    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.0503   |
# |    disc/disc_entropy                | 0.674    |
# |    disc/disc_loss                   | 0.704    |
# |    disc/disc_proportion_expert_pred | 0.975    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.524    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.0479   |
# |    disc/disc_entropy                | 0.675    |
# |    disc/disc_loss                   | 0.701    |
# |    disc/disc_proportion_expert_pred | 0.976    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.535    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.0698   |
# |    disc/disc_entropy                | 0.676    |
# |    disc/disc_loss                   | 0.697    |
# |    disc/disc_proportion_expert_pred | 0.965    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.533    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.0654   |
# |    disc/disc_entropy                | 0.677    |
# |    disc/disc_loss                   | 0.697    |
# |    disc/disc_proportion_expert_pred | 0.967    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.545    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.0903   |
# |    disc/disc_entropy                | 0.677    |
# |    disc/disc_loss                   | 0.691    |
# |    disc/disc_proportion_expert_pred | 0.955    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.552    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.105    |
# |    disc/disc_entropy                | 0.679    |
# |    disc/disc_loss                   | 0.685    |
# |    disc/disc_proportion_expert_pred | 0.948    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.57     |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.141    |
# |    disc/disc_entropy                | 0.679    |
# |    disc/disc_loss                   | 0.684    |
# |    disc/disc_proportion_expert_pred | 0.93     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# ---------------------------------------------------
# | mean/                               |           |
# |    disc/disc_acc                    | 0.523     |
# |    disc/disc_acc_expert             | 1         |
# |    disc/disc_acc_gen                | 0.0459    |
# |    disc/disc_entropy                | 0.672     |
# |    disc/disc_loss                   | 0.71      |
# |    disc/disc_proportion_expert_pred | 0.977     |
# |    disc/disc_proportion_expert_true | 0.5       |
# |    disc/global_step                 | 1         |
# |    disc/n_expert                    | 2.05e+03  |
# |    disc/n_generated                 | 2.05e+03  |
# |    gen/rollout/ep_len_mean          | 500       |
# |    gen/rollout/ep_rew_mean          | 34.4      |
# |    gen/time/fps                     | 7.6e+03   |
# |    gen/time/iterations              | 1         |
# |    gen/time/time_elapsed            | 2         |
# |    gen/time/total_timesteps         | 1.64e+04  |
# |    gen/train/approx_kl              | 0.000923  |
# |    gen/train/clip_fraction          | 0.026     |
# |    gen/train/clip_range             | 0.1       |
# |    gen/train/entropy_loss           | -0.692    |
# |    gen/train/explained_variance     | -0.0146   |
# |    gen/train/learning_rate          | 0.0005    |
# |    gen/train/loss                   | 4.4       |
# |    gen/train/n_updates              | 5         |
# |    gen/train/policy_gradient_loss   | -0.000137 |
# |    gen/train/value_loss             | 199       |
# ---------------------------------------------------
# round:   1%|          | 1/122 [00:04<08:50,  4.39s/it]
# -----------------------------------------------------
# | raw/                               |              |
# |    gen/rollout/ep_len_mean         | 500          |
# |    gen/rollout/ep_rew_mean         | 36.7         |
# |    gen/rollout/ep_rew_wrapped_mean | -572         |
# |    gen/time/fps                    | 7824         |
# |    gen/time/iterations             | 1            |
# |    gen/time/time_elapsed           | 2            |
# |    gen/time/total_timesteps        | 32768        |
# |    gen/train/approx_kl             | 0.0009234178 |
# |    gen/train/clip_fraction         | 0.026        |
# |    gen/train/clip_range            | 0.1          |
# |    gen/train/entropy_loss          | -0.692       |
# |    gen/train/explained_variance    | -0.0146      |
# |    gen/train/learning_rate         | 0.0005       |
# |    gen/train/loss                  | 4.4          |
# |    gen/train/n_updates             | 5            |
# |    gen/train/policy_gradient_loss  | -0.000137    |
# |    gen/train/value_loss            | 199          |
# -----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.61     |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.22     |
# |    disc/disc_entropy                | 0.68     |
# |    disc/disc_loss                   | 0.667    |
# |    disc/disc_proportion_expert_pred | 0.89     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.613    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.227    |
# |    disc/disc_entropy                | 0.681    |
# |    disc/disc_loss                   | 0.667    |
# |    disc/disc_proportion_expert_pred | 0.887    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.615    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.229    |
# |    disc/disc_entropy                | 0.681    |
# |    disc/disc_loss                   | 0.665    |
# |    disc/disc_proportion_expert_pred | 0.885    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.629    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.257    |
# |    disc/disc_entropy                | 0.681    |
# |    disc/disc_loss                   | 0.663    |
# |    disc/disc_proportion_expert_pred | 0.871    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.628    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.257    |
# |    disc/disc_entropy                | 0.681    |
# |    disc/disc_loss                   | 0.662    |
# |    disc/disc_proportion_expert_pred | 0.872    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.636    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.272    |
# |    disc/disc_entropy                | 0.681    |
# |    disc/disc_loss                   | 0.661    |
# |    disc/disc_proportion_expert_pred | 0.864    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.642    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.284    |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.66     |
# |    disc/disc_proportion_expert_pred | 0.858    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.641    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.282    |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.659    |
# |    disc/disc_proportion_expert_pred | 0.859    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.651    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.303    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.656    |
# |    disc/disc_proportion_expert_pred | 0.849    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.655    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.31     |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.656    |
# |    disc/disc_proportion_expert_pred | 0.845    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.654    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.309    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.656    |
# |    disc/disc_proportion_expert_pred | 0.846    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.667    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.333    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.653    |
# |    disc/disc_proportion_expert_pred | 0.833    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.665    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.331    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.652    |
# |    disc/disc_proportion_expert_pred | 0.835    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.668    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.335    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.651    |
# |    disc/disc_proportion_expert_pred | 0.832    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.667    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.334    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.653    |
# |    disc/disc_proportion_expert_pred | 0.833    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.678    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.355    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.647    |
# |    disc/disc_proportion_expert_pred | 0.822    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.645    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.29     |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.658    |
# |    disc/disc_proportion_expert_pred | 0.855    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 36.7     |
# |    gen/rollout/ep_rew_wrapped_mean  | -572     |
# |    gen/time/fps                     | 7.82e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 2        |
# |    gen/time/total_timesteps         | 3.28e+04 |
# |    gen/train/approx_kl              | 0.00234  |
# |    gen/train/clip_fraction          | 0.108    |
# |    gen/train/clip_range             | 0.1      |
# |    gen/train/entropy_loss           | -0.689   |
# |    gen/train/explained_variance     | 0.802    |
# |    gen/train/learning_rate          | 0.0005   |
# |    gen/train/loss                   | 0.0926   |
# |    gen/train/n_updates              | 10       |
# |    gen/train/policy_gradient_loss   | -0.0027  |
# |    gen/train/value_loss             | 1.55     |
# --------------------------------------------------
# round:   2%|▏         | 2/122 [00:08<08:39,  4.33s/it]
# -----------------------------------------------------
# | raw/                               |              |
# |    gen/rollout/ep_len_mean         | 500          |
# |    gen/rollout/ep_rew_mean         | 35.3         |
# |    gen/rollout/ep_rew_wrapped_mean | -441         |
# |    gen/time/fps                    | 7791         |
# |    gen/time/iterations             | 1            |
# |    gen/time/time_elapsed           | 2            |
# |    gen/time/total_timesteps        | 49152        |
# |    gen/train/approx_kl             | 0.0023373594 |
# |    gen/train/clip_fraction         | 0.108        |
# |    gen/train/clip_range            | 0.1          |
# |    gen/train/entropy_loss          | -0.689       |
# |    gen/train/explained_variance    | 0.802        |
# |    gen/train/learning_rate         | 0.0005       |
# |    gen/train/loss                  | 0.0926       |
# |    gen/train/n_updates             | 10           |
# |    gen/train/policy_gradient_loss  | -0.0027      |
# |    gen/train/value_loss            | 1.55         |
# -----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.716    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.432    |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.646    |
# |    disc/disc_proportion_expert_pred | 0.784    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.712    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.425    |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.648    |
# |    disc/disc_proportion_expert_pred | 0.788    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.72     |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.44     |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.648    |
# |    disc/disc_proportion_expert_pred | 0.78     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.732    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.465    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.644    |
# |    disc/disc_proportion_expert_pred | 0.768    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.734    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.467    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.645    |
# |    disc/disc_proportion_expert_pred | 0.766    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.735    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.47     |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.644    |
# |    disc/disc_proportion_expert_pred | 0.765    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.746    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.492    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.64     |
# |    disc/disc_proportion_expert_pred | 0.754    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.761    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.523    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.64     |
# |    disc/disc_proportion_expert_pred | 0.739    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.767    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.535    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.636    |
# |    disc/disc_proportion_expert_pred | 0.733    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.76     |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.521    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.64     |
# |    disc/disc_proportion_expert_pred | 0.74     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.77     |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.54     |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.635    |
# |    disc/disc_proportion_expert_pred | 0.73     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.781    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.562    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.632    |
# |    disc/disc_proportion_expert_pred | 0.719    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.786    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.572    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.629    |
# |    disc/disc_proportion_expert_pred | 0.714    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.788    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.576    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.627    |
# |    disc/disc_proportion_expert_pred | 0.712    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.803    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.605    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.624    |
# |    disc/disc_proportion_expert_pred | 0.697    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.802    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.605    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.623    |
# |    disc/disc_proportion_expert_pred | 0.698    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.757    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.514    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.638    |
# |    disc/disc_proportion_expert_pred | 0.743    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 35.3     |
# |    gen/rollout/ep_rew_wrapped_mean  | -441     |
# |    gen/time/fps                     | 7.79e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 2        |
# |    gen/time/total_timesteps         | 4.92e+04 |
# |    gen/train/approx_kl              | 0.00222  |
# |    gen/train/clip_fraction          | 0.116    |
# |    gen/train/clip_range             | 0.1      |
# |    gen/train/entropy_loss           | -0.687   |
# |    gen/train/explained_variance     | 0.904    |
# |    gen/train/learning_rate          | 0.0005   |
# |    gen/train/loss                   | 0.0987   |
# |    gen/train/n_updates              | 15       |
# |    gen/train/policy_gradient_loss   | -0.00371 |
# |    gen/train/value_loss             | 0.885    |
# --------------------------------------------------
# round:   2%|▏         | 3/122 [00:12<08:26,  4.26s/it]
# -----------------------------------------------------
# | raw/                               |              |
# |    gen/rollout/ep_len_mean         | 500          |
# |    gen/rollout/ep_rew_mean         | 35.6         |
# |    gen/rollout/ep_rew_wrapped_mean | -438         |
# |    gen/time/fps                    | 7770         |
# |    gen/time/iterations             | 1            |
# |    gen/time/time_elapsed           | 2            |
# |    gen/time/total_timesteps        | 65536        |
# |    gen/train/approx_kl             | 0.0022240467 |
# |    gen/train/clip_fraction         | 0.116        |
# |    gen/train/clip_range            | 0.1          |
# |    gen/train/entropy_loss          | -0.687       |
# |    gen/train/explained_variance    | 0.904        |
# |    gen/train/learning_rate         | 0.0005       |
# |    gen/train/loss                  | 0.0987       |
# |    gen/train/n_updates             | 15           |
# |    gen/train/policy_gradient_loss  | -0.00371     |
# |    gen/train/value_loss            | 0.885        |
# -----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.732    |
# |    disc/disc_acc_expert             | 0.975    |
# |    disc/disc_acc_gen                | 0.49     |
# |    disc/disc_entropy                | 0.679    |
# |    disc/disc_loss                   | 0.637    |
# |    disc/disc_proportion_expert_pred | 0.743    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.736    |
# |    disc/disc_acc_expert             | 0.968    |
# |    disc/disc_acc_gen                | 0.504    |
# |    disc/disc_entropy                | 0.679    |
# |    disc/disc_loss                   | 0.635    |
# |    disc/disc_proportion_expert_pred | 0.732    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.731    |
# |    disc/disc_acc_expert             | 0.967    |
# |    disc/disc_acc_gen                | 0.496    |
# |    disc/disc_entropy                | 0.679    |
# |    disc/disc_loss                   | 0.635    |
# |    disc/disc_proportion_expert_pred | 0.735    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.746    |
# |    disc/disc_acc_expert             | 0.969    |
# |    disc/disc_acc_gen                | 0.523    |
# |    disc/disc_entropy                | 0.68     |
# |    disc/disc_loss                   | 0.63     |
# |    disc/disc_proportion_expert_pred | 0.723    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.739    |
# |    disc/disc_acc_expert             | 0.964    |
# |    disc/disc_acc_gen                | 0.514    |
# |    disc/disc_entropy                | 0.679    |
# |    disc/disc_loss                   | 0.628    |
# |    disc/disc_proportion_expert_pred | 0.725    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.739    |
# |    disc/disc_acc_expert             | 0.969    |
# |    disc/disc_acc_gen                | 0.508    |
# |    disc/disc_entropy                | 0.68     |
# |    disc/disc_loss                   | 0.629    |
# |    disc/disc_proportion_expert_pred | 0.731    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.75     |
# |    disc/disc_acc_expert             | 0.965    |
# |    disc/disc_acc_gen                | 0.536    |
# |    disc/disc_entropy                | 0.679    |
# |    disc/disc_loss                   | 0.623    |
# |    disc/disc_proportion_expert_pred | 0.714    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.759    |
# |    disc/disc_acc_expert             | 0.975    |
# |    disc/disc_acc_gen                | 0.542    |
# |    disc/disc_entropy                | 0.679    |
# |    disc/disc_loss                   | 0.622    |
# |    disc/disc_proportion_expert_pred | 0.716    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.772    |
# |    disc/disc_acc_expert             | 0.979    |
# |    disc/disc_acc_gen                | 0.566    |
# |    disc/disc_entropy                | 0.679    |
# |    disc/disc_loss                   | 0.618    |
# |    disc/disc_proportion_expert_pred | 0.706    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.772    |
# |    disc/disc_acc_expert             | 0.983    |
# |    disc/disc_acc_gen                | 0.561    |
# |    disc/disc_entropy                | 0.679    |
# |    disc/disc_loss                   | 0.618    |
# |    disc/disc_proportion_expert_pred | 0.711    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.78     |
# |    disc/disc_acc_expert             | 0.991    |
# |    disc/disc_acc_gen                | 0.568    |
# |    disc/disc_entropy                | 0.679    |
# |    disc/disc_loss                   | 0.615    |
# |    disc/disc_proportion_expert_pred | 0.711    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.782    |
# |    disc/disc_acc_expert             | 0.995    |
# |    disc/disc_acc_gen                | 0.569    |
# |    disc/disc_entropy                | 0.679    |
# |    disc/disc_loss                   | 0.615    |
# |    disc/disc_proportion_expert_pred | 0.713    |
# |    disc/disc_proportion_expert_true | 0.5      |
# ...
# |    disc/disc_acc_gen                | 0.951    |
# |    disc/disc_entropy                | 0.582    |
# |    disc/disc_loss                   | 0.495    |
# |    disc/disc_proportion_expert_pred | 0.361    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 121      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.804    |
# |    disc/disc_acc_expert             | 0.664    |
# |    disc/disc_acc_gen                | 0.944    |
# |    disc/disc_entropy                | 0.587    |
# |    disc/disc_loss                   | 0.506    |
# |    disc/disc_proportion_expert_pred | 0.36     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 121      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.783    |
# |    disc/disc_acc_expert             | 0.622    |
# |    disc/disc_acc_gen                | 0.945    |
# |    disc/disc_entropy                | 0.58     |
# |    disc/disc_loss                   | 0.507    |
# |    disc/disc_proportion_expert_pred | 0.338    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 121      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 500      |
# |    gen/rollout/ep_rew_wrapped_mean  | -101     |
# |    gen/time/fps                     | 7.9e+03  |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 2        |
# |    gen/time/total_timesteps         | 1.98e+06 |
# |    gen/train/approx_kl              | 0.00111  |
# |    gen/train/clip_fraction          | 0.0367   |
# |    gen/train/clip_range             | 0.1      |
# |    gen/train/entropy_loss           | -0.151   |
# |    gen/train/explained_variance     | 0.994    |
# |    gen/train/learning_rate          | 0.0005   |
# |    gen/train/loss                   | 0.011    |
# |    gen/train/n_updates              | 605      |
# |    gen/train/policy_gradient_loss   | 0.000833 |
# |    gen/train/value_loss             | 0.109    |
# --------------------------------------------------
# round:  99%|█████████▉| 121/122 [08:28<00:04,  4.20s/it]
# -----------------------------------------------------
# | raw/                               |              |
# |    gen/rollout/ep_len_mean         | 500          |
# |    gen/rollout/ep_rew_mean         | 500          |
# |    gen/rollout/ep_rew_wrapped_mean | -117         |
# |    gen/time/fps                    | 7497         |
# |    gen/time/iterations             | 1            |
# |    gen/time/time_elapsed           | 2            |
# |    gen/time/total_timesteps        | 1998848      |
# |    gen/train/approx_kl             | 0.0011095797 |
# |    gen/train/clip_fraction         | 0.0367       |
# |    gen/train/clip_range            | 0.1          |
# |    gen/train/entropy_loss          | -0.151       |
# |    gen/train/explained_variance    | 0.994        |
# |    gen/train/learning_rate         | 0.0005       |
# |    gen/train/loss                  | 0.011        |
# |    gen/train/n_updates             | 605          |
# |    gen/train/policy_gradient_loss  | 0.000833     |
# |    gen/train/value_loss            | 0.109        |
# -----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.603    |
# |    disc/disc_acc_expert             | 0.675    |
# |    disc/disc_acc_gen                | 0.532    |
# |    disc/disc_entropy                | 0.597    |
# |    disc/disc_loss                   | 0.646    |
# |    disc/disc_proportion_expert_pred | 0.572    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 122      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.613    |
# |    disc/disc_acc_expert             | 0.688    |
# |    disc/disc_acc_gen                | 0.538    |
# |    disc/disc_entropy                | 0.598    |
# |    disc/disc_loss                   | 0.641    |
# |    disc/disc_proportion_expert_pred | 0.575    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 122      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.607    |
# |    disc/disc_acc_expert             | 0.694    |
# |    disc/disc_acc_gen                | 0.52     |
# |    disc/disc_entropy                | 0.597    |
# |    disc/disc_loss                   | 0.646    |
# |    disc/disc_proportion_expert_pred | 0.587    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 122      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.595    |
# |    disc/disc_acc_expert             | 0.681    |
# |    disc/disc_acc_gen                | 0.509    |
# |    disc/disc_entropy                | 0.606    |
# |    disc/disc_loss                   | 0.648    |
# |    disc/disc_proportion_expert_pred | 0.586    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 122      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.599    |
# |    disc/disc_acc_expert             | 0.666    |
# |    disc/disc_acc_gen                | 0.532    |
# |    disc/disc_entropy                | 0.604    |
# |    disc/disc_loss                   | 0.645    |
# |    disc/disc_proportion_expert_pred | 0.567    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 122      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.608    |
# |    disc/disc_acc_expert             | 0.675    |
# |    disc/disc_acc_gen                | 0.541    |
# |    disc/disc_entropy                | 0.604    |
# |    disc/disc_loss                   | 0.643    |
# |    disc/disc_proportion_expert_pred | 0.567    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 122      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.616    |
# |    disc/disc_acc_expert             | 0.666    |
# |    disc/disc_acc_gen                | 0.567    |
# |    disc/disc_entropy                | 0.602    |
# |    disc/disc_loss                   | 0.646    |
# |    disc/disc_proportion_expert_pred | 0.549    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 122      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.609    |
# |    disc/disc_acc_expert             | 0.658    |
# |    disc/disc_acc_gen                | 0.561    |
# |    disc/disc_entropy                | 0.605    |
# |    disc/disc_loss                   | 0.65     |
# |    disc/disc_proportion_expert_pred | 0.549    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 122      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.619    |
# |    disc/disc_acc_expert             | 0.649    |
# |    disc/disc_acc_gen                | 0.589    |
# |    disc/disc_entropy                | 0.602    |
# |    disc/disc_loss                   | 0.642    |
# |    disc/disc_proportion_expert_pred | 0.53     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 122      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.613    |
# |    disc/disc_acc_expert             | 0.622    |
# |    disc/disc_acc_gen                | 0.604    |
# |    disc/disc_entropy                | 0.607    |
# |    disc/disc_loss                   | 0.641    |
# |    disc/disc_proportion_expert_pred | 0.509    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 122      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.614    |
# |    disc/disc_acc_expert             | 0.613    |
# |    disc/disc_acc_gen                | 0.615    |
# |    disc/disc_entropy                | 0.608    |
# |    disc/disc_loss                   | 0.644    |
# |    disc/disc_proportion_expert_pred | 0.499    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 122      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.612    |
# |    disc/disc_acc_expert             | 0.598    |
# |    disc/disc_acc_gen                | 0.625    |
# |    disc/disc_entropy                | 0.606    |
# |    disc/disc_loss                   | 0.641    |
# |    disc/disc_proportion_expert_pred | 0.487    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 122      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.602    |
# |    disc/disc_acc_expert             | 0.584    |
# |    disc/disc_acc_gen                | 0.621    |
# |    disc/disc_entropy                | 0.598    |
# |    disc/disc_loss                   | 0.641    |
# |    disc/disc_proportion_expert_pred | 0.482    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 122      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.601    |
# |    disc/disc_acc_expert             | 0.565    |
# |    disc/disc_acc_gen                | 0.638    |
# |    disc/disc_entropy                | 0.605    |
# |    disc/disc_loss                   | 0.643    |
# |    disc/disc_proportion_expert_pred | 0.464    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 122      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.604    |
# |    disc/disc_acc_expert             | 0.556    |
# |    disc/disc_acc_gen                | 0.652    |
# |    disc/disc_entropy                | 0.603    |
# |    disc/disc_loss                   | 0.639    |
# |    disc/disc_proportion_expert_pred | 0.452    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 122      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.609    |
# |    disc/disc_acc_expert             | 0.547    |
# |    disc/disc_acc_gen                | 0.671    |
# |    disc/disc_entropy                | 0.604    |
# |    disc/disc_loss                   | 0.646    |
# |    disc/disc_proportion_expert_pred | 0.438    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 122      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.608    |
# |    disc/disc_acc_expert             | 0.634    |
# |    disc/disc_acc_gen                | 0.582    |
# |    disc/disc_entropy                | 0.603    |
# |    disc/disc_loss                   | 0.644    |
# |    disc/disc_proportion_expert_pred | 0.526    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 122      |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 500      |
# |    gen/rollout/ep_rew_wrapped_mean  | -117     |
# |    gen/time/fps                     | 7.5e+03  |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 2        |
# |    gen/time/total_timesteps         | 2e+06    |
# |    gen/train/approx_kl              | 0.00149  |
# |    gen/train/clip_fraction          | 0.0474   |
# |    gen/train/clip_range             | 0.1      |
# |    gen/train/entropy_loss           | -0.146   |
# |    gen/train/explained_variance     | 0.995    |
# |    gen/train/learning_rate          | 0.0005   |
# |    gen/train/loss                   | 0.00618  |
# |    gen/train/n_updates              | 610      |
# |    gen/train/policy_gradient_loss   | 0.000509 |
# |    gen/train/value_loss             | 0.0799   |
# --------------------------------------------------
# round: 100%|██████████| 122/122 [08:32<00:00,  4.20s/it]

# %% [markdown]
# Visualization of trained Learner Policy (AIRL Generator):

# %%
import gymnasium as gym
import os
from IPython.display import display, clear_output
import matplotlib.pyplot as plt

render_mode = "human" if os.environ.get('DISPLAY') else "rgb_array"
env = gym.make("seals:seals/CartPole-v0", render_mode=render_mode)

# Gymnasium returns (obs, info) from reset(); unpack so `obs` is the raw observation
obs, info = env.reset()

for _ in range(1000):
    # Pass only the observation (not the (obs, info) tuple) to the SB3 policy
    action, _ = learner.predict(obs, deterministic=True)

    # Gymnasium step returns (obs, reward, terminated, truncated, info)
    obs, rew, terminated, truncated, info = env.step(action)

    # Render depending on mode. For `rgb_array` we collect and display frames inside the notebook.
    if render_mode == "rgb_array":
        frame = env.render()
        # display every 10 frames to avoid excessive output
        if (_ % 10) == 0:
            clear_output(wait=True)
            plt.imshow(frame)
            plt.axis('off')
            display(plt.gcf())
    else:
        env.render()   # opens a window (when DISPLAY is available)

    # episode end when either terminated or truncated
    if terminated or truncated:
        obs, info = env.reset()
        # if running in rgb_array mode, break after one episode to show the frames
        if render_mode == "rgb_array":
            break

env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 17
#      14 action, _ = learner.predict(obs, deterministic=True)
#      16 # Gymnasium step returns (obs, reward, terminated, truncated, info)
# ---> 17 obs, rew, terminated, truncated, info = env.step(action)
#      19 # Render depending on mode. For `rgb_array` we collect and display frames inside the notebook.
#      20 if render_mode == "rgb_array":
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/gymnasium/wrappers/time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)     55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/gymnasium/wrappers/env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/seals/classic_control.py:53, in FixedHorizonCartPole.step(self, action)
#      49 with warnings.catch_warnings():
#      50     # Filter out CartPoleEnv warning for calling step() beyond
#      51     # terminated=True or truncated=True
#      52     warnings.filterwarnings("ignore", ".*You are calling.*")
# ---> 53     super().step(action)
#      55 self.state = list(self.state)
#      56 x, _, theta, _ = self.state
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/gymnasium/envs/classic_control/cartpole.py:190, in CartPoleEnv.step(self, action)
#     187     reward = 0.0
#     189 if self.render_mode == "human":
# --> 190     self.render()
#     191 return np.array(self.state, dtype=np.float32), reward, terminated, False, {}
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/gymnasium/envs/classic_control/cartpole.py:302, in CartPoleEnv.render(self)
#     300 if self.render_mode == "human":
#     301     pygame.event.pump()
# --> 302     self.clock.tick(self.metadata["render_fps"])
#     303     pygame.display.flip()
#     305 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:

# %% [markdown]
# We can see that an untrained policy performs poorly, while AIRL brings an improvement.

# %%
print(
    "Rewards before training:",
    np.mean(learner_rewards_before_training),
    "+/-",
    np.std(learner_rewards_before_training),
)
print(
    "Rewards after training:",
    np.mean(learner_rewards_after_training),
    "+/-",
    np.std(learner_rewards_after_training),
)
# Out:
# Rewards before training: 102.6 +/- 24.11514047232568
# Rewards after training: 500.0 +/- 0.0

# %% [markdown]
# Training preparation of RL Agent with AIRL Reward Net:

# %%
# Use learned reward_net as reward function (SAC if continuous, DQN if discrete).
# The wrapper replaces the environment reward with reward_net.predict_processed(...).
import numpy as np
import gymnasium as gym
from stable_baselines3 import SAC, DQN
from stable_baselines3.sac import MlpPolicy as SACPolicy
from stable_baselines3.dqn import MlpPolicy as DQNPolicy
from stable_baselines3.common.evaluation import evaluate_policy

# Choose the reward net: prefer airl_trainer.reward_test if available
base_reward_net = None
if 'airl_trainer' in globals() and getattr(globals()['airl_trainer'], 'reward_test', None) is not None:
    base_reward_net = globals()['airl_trainer'].reward_test
    print('Using airl_trainer.reward_test as reward_net.')
elif 'reward_net' in globals():
    base_reward_net = globals()['reward_net']
    print('Using reward_net as reward_net.')
else:
    raise RuntimeError('Kein reward_net gefunden. Führe zuerst die AIRL-Zellen aus.')

class RewardNetRewardWrapper(gym.Wrapper):
    """Env wrapper that replaces the environment reward with a learned reward_net.
    Expects observations to be plain ndarrays (not Dict obs).
    """
    def __init__(self, env, reward_net):
        super().__init__(env)
        self.reward_net = reward_net
        self.last_obs = None

    def reset(self, **kwargs):
        res = self.env.reset(**kwargs)
        if isinstance(res, tuple):
            obs, info = res
        else:
            obs, info = res, {}
        self.last_obs = np.asarray(obs)
        return res

    def step(self, action):
        next_obs, _, terminated, truncated, info = self.env.step(action)
        done = bool(terminated or truncated)
        s = np.expand_dims(np.asarray(self.last_obs), 0)
        a = np.expand_dims(np.asarray(action), 0)
        ns = np.expand_dims(np.asarray(next_obs), 0)
        d = np.array([done], dtype=float)
        # use predict_processed if available
        if hasattr(self.reward_net, 'predict_processed'):
            r = float(self.reward_net.predict_processed(s, a, ns, d)[0])
        else:
            r = float(self.reward_net.predict(s, a, ns, d)[0])
        self.last_obs = np.asarray(next_obs)
        return next_obs, r, terminated, truncated, info

# Create base env and wrap
base_env = gym.make('seals:seals/CartPole-v0')
wrapped_env = RewardNetRewardWrapper(base_env, base_reward_net)

# Choose algorithm compatible with action space
# We imported `gymnasium as gym` above; avoid importing the legacy `gym` package.
if isinstance(wrapped_env.action_space, gym.spaces.Box):
    Algo = SAC
    Policy = SACPolicy
    print('Using SAC for continuous action space.')
else:
    # Discrete action spaces -> use DQN
    Algo = DQN
    Policy = DQNPolicy
    print('Using DQN for discrete action space.')

agent = Algo(Policy, wrapped_env, verbose=1, seed=SEED)
# Out:
# Using airl_trainer.reward_test as reward_net.
# Using DQN for discrete action space.
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# Visualization of RL Policy before training:

# %%
render_mode = "human" if os.environ.get('DISPLAY') else "rgb_array"
env = gym.make("seals:seals/CartPole-v0", render_mode=render_mode)

# Gymnasium returns (obs, info) from reset(); unpack so `obs` is the raw observation
obs, info = env.reset()

for _ in range(100):
    # Pass only the observation (not the (obs, info) tuple) to the SB3 policy
    action, _ = agent.predict(obs, deterministic=True)

    # Gymnasium step returns (obs, reward, terminated, truncated, info)
    obs, rew, terminated, truncated, info = env.step(action)

    # Render depending on mode. For `rgb_array` we collect and display frames inside the notebook.
    if render_mode == "rgb_array":
        frame = env.render()
        # display every 10 frames to avoid excessive output
        if (_ % 10) == 0:
            clear_output(wait=True)
            plt.imshow(frame)
            plt.axis('off')
            display(plt.gcf())
    else:
        env.render()   # opens a window (when DISPLAY is available)

    # episode end when either terminated or truncated
    if terminated or truncated:
        obs, info = env.reset()
        # if running in rgb_array mode, break after one episode to show the frames
        if render_mode == "rgb_array":
            break

env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 24
#      22         display(plt.gcf())
#      23 else:
# ---> 24     env.render()   # opens a window (when DISPLAY is available)
#      26 # episode end when either terminated or truncated
#      27 if terminated or truncated:
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/gymnasium/core.py:471, in Wrapper.render(self)
#     469 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     470     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 471     return self.env.render()
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/gymnasium/wrappers/order_enforcing.py:70, in OrderEnforcing.render(self, *args, **kwargs)
#      65 if not self._disable_render_order_enforcing and not self._has_reset:
#      66     raise ResetNeeded(
#      67         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      68         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      69     )
# ---> 70 return self.env.render(*args, **kwargs)
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/gymnasium/wrappers/env_checker.py:67, in PassiveEnvChecker.render(self, *args, **kwargs)
#      65     return env_render_passive_checker(self.env, *args, **kwargs)
#      66 else:
# ---> 67     return self.env.render(*args, **kwargs)
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/gymnasium/envs/classic_control/cartpole.py:302, in CartPoleEnv.render(self)
#     300 if self.render_mode == "human":
#     301     pygame.event.pump()
# --> 302     self.clock.tick(self.metadata["render_fps"])
#     303     pygame.display.flip()
#     305 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:

# %% [markdown]
# Training RL Agent with AIRL Reward Net:

# %%
total_timesteps = 5000000
agent.learn(total_timesteps=total_timesteps)

# Evaluation (return_episode_rewards=True returns (episode_rewards, episode_lengths))
episode_rewards, episode_lengths = evaluate_policy(agent, wrapped_env, n_eval_episodes=10, return_episode_rewards=True)
print('Mean return (10 eps):', np.mean(episode_rewards))

# Save agent
agent.save('agent_with_learned_reward')
# Out:
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -9.86e+03 |
# |    exploration_rate | 0.996     |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 3478      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 2000      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.32e+04 |
# |    exploration_rate | 0.992     |
# | time/               |           |
# |    episodes         | 8         |
# |    fps              | 3485      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 4000      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.74e+04 |
# |    exploration_rate | 0.989     |
# | time/               |           |
# |    episodes         | 12        |
# |    fps              | 3496      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 6000      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.37e+04 |
# |    exploration_rate | 0.985     |
# | time/               |           |
# |    episodes         | 16        |
# |    fps              | 3502      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 8000      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.17e+04 |
# |    exploration_rate | 0.981     |
# | time/               |           |
# |    episodes         | 20        |
# |    fps              | 3489      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 10000     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.02e+04 |
# |    exploration_rate | 0.977     |
# | time/               |           |
# |    episodes         | 24        |
# |    fps              | 3494      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 12000     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.04e+04 |
# |    exploration_rate | 0.973     |
# | time/               |           |
# |    episodes         | 28        |
# |    fps              | 3494      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 14000     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.89e+04 |
# |    exploration_rate | 0.97      |
# | time/               |           |
# |    episodes         | 32        |
# |    fps              | 3492      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 16000     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.77e+04 |
# |    exploration_rate | 0.966     |
# | time/               |           |
# |    episodes         | 36        |
# |    fps              | 3495      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 18000     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.79e+04 |
# |    exploration_rate | 0.962     |
# | time/               |           |
# |    episodes         | 40        |
# |    fps              | 3493      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 20000     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.75e+04 |
# |    exploration_rate | 0.958     |
# | time/               |           |
# |    episodes         | 44        |
# |    fps              | 3495      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 22000     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.73e+04 |
# |    exploration_rate | 0.954     |
# | time/               |           |
# |    episodes         | 48        |
# |    fps              | 3500      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 24000     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.69e+04 |
# |    exploration_rate | 0.951     |
# | time/               |           |
# |    episodes         | 52        |
# |    fps              | 3503      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 26000     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.68e+04 |
# |    exploration_rate | 0.947     |
# | time/               |           |
# |    episodes         | 56        |
# |    fps              | 3504      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 28000     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.63e+04 |
# |    exploration_rate | 0.943     |
# | time/               |           |
# |    episodes         | 60        |
# |    fps              | 3506      |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 30000     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.68e+04 |
# |    exploration_rate | 0.939     |
# | time/               |           |
# |    episodes         | 64        |
# |    fps              | 3507      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 32000     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.65e+04 |
# |    exploration_rate | 0.935     |
# | time/               |           |
# |    episodes         | 68        |
# |    fps              | 3509      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 34000     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.65e+04 |
# |    exploration_rate | 0.932     |
# | time/               |           |
# |    episodes         | 72        |
# |    fps              | 3510      |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 36000     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.74e+04 |
# |    exploration_rate | 0.928     |
# | time/               |           |
# |    episodes         | 76        |
# |    fps              | 3511      |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 38000     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.71e+04 |
# |    exploration_rate | 0.924     |
# | time/               |           |
# |    episodes         | 80        |
# |    fps              | 3512      |
# |    time_elapsed     | 11        |
# |    total_timesteps  | 40000     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -1.7e+04 |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 3515     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 42000    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.68e+04 |
# |    exploration_rate | 0.916     |
# | time/               |           |
# |    episodes         | 88        |
# |    fps              | 3518      |
# |    time_elapsed     | 12        |
# |    total_timesteps  | 44000     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.69e+04 |
# |    exploration_rate | 0.913     |
# | time/               |           |
# |    episodes         | 92        |
# |    fps              | 3520      |
# |    time_elapsed     | 13        |
# |    total_timesteps  | 46000     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.72e+04 |
# |    exploration_rate | 0.909     |
# | time/               |           |
# |    episodes         | 96        |
# |    fps              | 3522      |
# |    time_elapsed     | 13        |
# |    total_timesteps  | 48000     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -1.8e+04 |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 3523     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 50000    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.84e+04 |
# |    exploration_rate | 0.901     |
# | time/               |           |
# |    episodes         | 104       |
# |    fps              | 3410      |
# |    time_elapsed     | 15        |
# |    total_timesteps  | 52000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 11.4      |
# |    n_updates        | 499       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.96e+04 |
# |    exploration_rate | 0.897     |
# | time/               |           |
# |    episodes         | 108       |
# |    fps              | 3309      |
# |    time_elapsed     | 16        |
# |    total_timesteps  | 54000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.5       |
# |    n_updates        | 999       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.91e+04 |
# |    exploration_rate | 0.894     |
# | time/               |           |
# |    episodes         | 112       |
# |    fps              | 3225      |
# |    time_elapsed     | 17        |
# |    total_timesteps  | 56000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.45      |
# |    n_updates        | 1499      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -1.8e+04 |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 3149     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 58000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.05     |
# |    n_updates        | 1999     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.93e+04 |
# |    exploration_rate | 0.886     |
# | time/               |           |
# |    episodes         | 120       |
# |    fps              | 3081      |
# |    time_elapsed     | 19        |
# |    total_timesteps  | 60000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.47      |
# |    n_updates        | 2499      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -2e+04   |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 3020     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 62000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.15     |
# |    n_updates        | 2999     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -2e+04   |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 2962     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 64000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.08     |
# |    n_updates        | 3499     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.06e+04 |
# |    exploration_rate | 0.875     |
# | time/               |           |
# |    episodes         | 132       |
# |    fps              | 2911      |
# |    time_elapsed     | 22        |
# |    total_timesteps  | 66000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.993     |
# |    n_updates        | 3999      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -2.1e+04 |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 2865     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 68000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.12     |
# |    n_updates        | 4499     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.14e+04 |
# |    exploration_rate | 0.867     |
# | time/               |           |
# |    episodes         | 140       |
# |    fps              | 2823      |
# |    time_elapsed     | 24        |
# |    total_timesteps  | 70000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.614     |
# |    n_updates        | 4999      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.17e+04 |
# |    exploration_rate | 0.863     |
# | time/               |           |
# |    episodes         | 144       |
# |    fps              | 2785      |
# |    time_elapsed     | 25        |
# |    total_timesteps  | 72000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.69      |
# |    n_updates        | 5499      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.18e+04 |
# |    exploration_rate | 0.859     |
# | time/               |           |
# |    episodes         | 148       |
# |    fps              | 2750      |
# |    time_elapsed     | 26        |
# |    total_timesteps  | 74000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.863     |
# |    n_updates        | 5999      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.21e+04 |
# |    exploration_rate | 0.856     |
# | time/               |           |
# |    episodes         | 152       |
# |    fps              | 2717      |
# |    time_elapsed     | 27        |
# |    total_timesteps  | 76000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.48      |
# |    n_updates        | 6499      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.22e+04 |
# |    exploration_rate | 0.852     |
# | time/               |           |
# |    episodes         | 156       |
# |    fps              | 2686      |
# |    time_elapsed     | 29        |
# |    total_timesteps  | 78000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.04      |
# |    n_updates        | 6999      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.28e+04 |
# |    exploration_rate | 0.848     |
# | time/               |           |
# |    episodes         | 160       |
# |    fps              | 2657      |
# |    time_elapsed     | 30        |
# |    total_timesteps  | 80000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.439     |
# |    n_updates        | 7499      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.35e+04 |
# |    exploration_rate | 0.844     |
# | time/               |           |
# |    episodes         | 164       |
# |    fps              | 2630      |
# |    time_elapsed     | 31        |
# |    total_timesteps  | 82000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.81      |
# |    n_updates        | 7999      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.36e+04 |
# |    exploration_rate | 0.84      |
# | time/               |           |
# |    episodes         | 168       |
# |    fps              | 2605      |
# |    time_elapsed     | 32        |
# |    total_timesteps  | 84000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.92      |
# |    n_updates        | 8499      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.37e+04 |
# |    exploration_rate | 0.837     |
# | time/               |           |
# |    episodes         | 172       |
# |    fps              | 2582      |
# |    time_elapsed     | 33        |
# |    total_timesteps  | 86000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.07      |
# |    n_updates        | 8999      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.31e+04 |
# |    exploration_rate | 0.833     |
# | time/               |           |
# |    episodes         | 176       |
# |    fps              | 2560      |
# |    time_elapsed     | 34        |
# |    total_timesteps  | 88000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.2       |
# |    n_updates        | 9499      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.33e+04 |
# |    exploration_rate | 0.829     |
# | time/               |           |
# |    episodes         | 180       |
# |    fps              | 2539      |
# |    time_elapsed     | 35        |
# |    total_timesteps  | 90000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.5       |
# |    n_updates        | 9999      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.38e+04 |
# |    exploration_rate | 0.825     |
# | time/               |           |
# |    episodes         | 184       |
# |    fps              | 2519      |
# |    time_elapsed     | 36        |
# |    total_timesteps  | 92000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.836     |
# |    n_updates        | 10499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.39e+04 |
# |    exploration_rate | 0.821     |
# | time/               |           |
# |    episodes         | 188       |
# |    fps              | 2499      |
# |    time_elapsed     | 37        |
# |    total_timesteps  | 94000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.28      |
# |    n_updates        | 10999     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -2.4e+04 |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 2481     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 96000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.435    |
# |    n_updates        | 11499    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.38e+04 |
# |    exploration_rate | 0.814     |
# | time/               |           |
# |    episodes         | 196       |
# |    fps              | 2465      |
# |    time_elapsed     | 39        |
# |    total_timesteps  | 98000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.66      |
# |    n_updates        | 11999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.32e+04 |
# |    exploration_rate | 0.81      |
# | time/               |           |
# |    episodes         | 200       |
# |    fps              | 2448      |
# |    time_elapsed     | 40        |
# |    total_timesteps  | 100000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.56      |
# |    n_updates        | 12499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.34e+04 |
# |    exploration_rate | 0.806     |
# | time/               |           |
# |    episodes         | 204       |
# |    fps              | 2432      |
# |    time_elapsed     | 41        |
# |    total_timesteps  | 102000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.84      |
# |    n_updates        | 12999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.25e+04 |
# |    exploration_rate | 0.802     |
# | time/               |           |
# |    episodes         | 208       |
# |    fps              | 2417      |
# |    time_elapsed     | 43        |
# |    total_timesteps  | 104000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.798     |
# |    n_updates        | 13499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.28e+04 |
# |    exploration_rate | 0.799     |
# | time/               |           |
# |    episodes         | 212       |
# |    fps              | 2402      |
# |    time_elapsed     | 44        |
# |    total_timesteps  | 106000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.953     |
# |    n_updates        | 13999     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -2.3e+04 |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 2389     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 108000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.757    |
# |    n_updates        | 14499    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.19e+04 |
# |    exploration_rate | 0.791     |
# | time/               |           |
# |    episodes         | 220       |
# |    fps              | 2377      |
# |    time_elapsed     | 46        |
# |    total_timesteps  | 110000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.16      |
# |    n_updates        | 14999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.16e+04 |
# |    exploration_rate | 0.787     |
# | time/               |           |
# |    episodes         | 224       |
# |    fps              | 2365      |
# |    time_elapsed     | 47        |
# |    total_timesteps  | 112000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 7         |
# |    n_updates        | 15499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.15e+04 |
# |    exploration_rate | 0.783     |
# | time/               |           |
# |    episodes         | 228       |
# |    fps              | 2353      |
# |    time_elapsed     | 48        |
# |    total_timesteps  | 114000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.534     |
# |    n_updates        | 15999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.12e+04 |
# |    exploration_rate | 0.78      |
# | time/               |           |
# |    episodes         | 232       |
# |    fps              | 2342      |
# |    time_elapsed     | 49        |
# |    total_timesteps  | 116000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.35      |
# |    n_updates        | 16499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.09e+04 |
# |    exploration_rate | 0.776     |
# | time/               |           |
# |    episodes         | 236       |
# |    fps              | 2331      |
# |    time_elapsed     | 50        |
# |    total_timesteps  | 118000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.89      |
# |    n_updates        | 16999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.02e+04 |
# |    exploration_rate | 0.772     |
# | time/               |           |
# |    episodes         | 240       |
# |    fps              | 2322      |
# |    time_elapsed     | 51        |
# |    total_timesteps  | 120000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.574     |
# |    n_updates        | 17499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.03e+04 |
# |    exploration_rate | 0.768     |
# | time/               |           |
# |    episodes         | 244       |
# |    fps              | 2311      |
# |    time_elapsed     | 52        |
# |    total_timesteps  | 122000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.11      |
# |    n_updates        | 17999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -2.01e+04 |
# |    exploration_rate | 0.764     |
# | time/               |           |
# |    episodes         | 248       |
# |    fps              | 2302      |
# |    time_elapsed     | 53        |
# |    total_timesteps  | 124000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.3       |
# |    n_updates        | 18499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.99e+04 |
# |    exploration_rate | 0.761     |
# | time/               |           |
# |    episodes         | 252       |
# |    fps              | 2293      |
# |    time_elapsed     | 54        |
# |    total_timesteps  | 126000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.764     |
# |    n_updates        | 18999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.97e+04 |
# |    exploration_rate | 0.757     |
# | time/               |           |
# |    episodes         | 256       |
# |    fps              | 2284      |
# |    time_elapsed     | 56        |
# |    total_timesteps  | 128000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.53      |
# |    n_updates        | 19499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.94e+04 |
# |    exploration_rate | 0.753     |
# | time/               |           |
# |    episodes         | 260       |
# |    fps              | 2275      |
# |    time_elapsed     | 57        |
# |    total_timesteps  | 130000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.547     |
# |    n_updates        | 19999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.82e+04 |
# |    exploration_rate | 0.749     |
# | time/               |           |
# |    episodes         | 264       |
# |    fps              | 2267      |
# |    time_elapsed     | 58        |
# |    total_timesteps  | 132000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.84      |
# |    n_updates        | 20499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.84e+04 |
# |    exploration_rate | 0.745     |
# | time/               |           |
# |    episodes         | 268       |
# |    fps              | 2259      |
# |    time_elapsed     | 59        |
# |    total_timesteps  | 134000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.38      |
# |    n_updates        | 20999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.81e+04 |
# |    exploration_rate | 0.742     |
# | time/               |           |
# |    episodes         | 272       |
# |    fps              | 2251      |
# |    time_elapsed     | 60        |
# |    total_timesteps  | 136000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.81      |
# |    n_updates        | 21499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.78e+04 |
# |    exploration_rate | 0.738     |
# | time/               |           |
# |    episodes         | 276       |
# |    fps              | 2243      |
# |    time_elapsed     | 61        |
# |    total_timesteps  | 138000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.3       |
# |    n_updates        | 21999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.74e+04 |
# |    exploration_rate | 0.734     |
# | time/               |           |
# |    episodes         | 280       |
# |    fps              | 2235      |
# |    time_elapsed     | 62        |
# |    total_timesteps  | 140000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.71      |
# |    n_updates        | 22499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.69e+04 |
# |    exploration_rate | 0.73      |
# | time/               |           |
# |    episodes         | 284       |
# |    fps              | 2227      |
# |    time_elapsed     | 63        |
# |    total_timesteps  | 142000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 10.2      |
# |    n_updates        | 22999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.68e+04 |
# |    exploration_rate | 0.726     |
# | time/               |           |
# |    episodes         | 288       |
# |    fps              | 2220      |
# |    time_elapsed     | 64        |
# |    total_timesteps  | 144000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.18      |
# |    n_updates        | 23499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.65e+04 |
# |    exploration_rate | 0.723     |
# | time/               |           |
# |    episodes         | 292       |
# |    fps              | 2212      |
# |    time_elapsed     | 65        |
# |    total_timesteps  | 146000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.94      |
# |    n_updates        | 23999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.65e+04 |
# |    exploration_rate | 0.719     |
# | time/               |           |
# |    episodes         | 296       |
# |    fps              | 2205      |
# |    time_elapsed     | 67        |
# |    total_timesteps  | 148000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.47      |
# |    n_updates        | 24499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.59e+04 |
# |    exploration_rate | 0.715     |
# | time/               |           |
# |    episodes         | 300       |
# |    fps              | 2198      |
# |    time_elapsed     | 68        |
# |    total_timesteps  | 150000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.16      |
# |    n_updates        | 24999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.56e+04 |
# |    exploration_rate | 0.711     |
# | time/               |           |
# |    episodes         | 304       |
# |    fps              | 2191      |
# |    time_elapsed     | 69        |
# |    total_timesteps  | 152000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.924     |
# |    n_updates        | 25499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.51e+04 |
# |    exploration_rate | 0.707     |
# | time/               |           |
# |    episodes         | 308       |
# |    fps              | 2185      |
# |    time_elapsed     | 70        |
# |    total_timesteps  | 154000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.917     |
# |    n_updates        | 25999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.48e+04 |
# |    exploration_rate | 0.704     |
# | time/               |           |
# |    episodes         | 312       |
# |    fps              | 2179      |
# |    time_elapsed     | 71        |
# |    total_timesteps  | 156000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.64      |
# |    n_updates        | 26499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.46e+04 |
# |    exploration_rate | 0.7       |
# | time/               |           |
# |    episodes         | 316       |
# |    fps              | 2173      |
# |    time_elapsed     | 72        |
# |    total_timesteps  | 158000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.68      |
# |    n_updates        | 26999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.44e+04 |
# |    exploration_rate | 0.696     |
# | time/               |           |
# |    episodes         | 320       |
# |    fps              | 2167      |
# |    time_elapsed     | 73        |
# |    total_timesteps  | 160000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.9       |
# |    n_updates        | 27499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.38e+04 |
# |    exploration_rate | 0.692     |
# | time/               |           |
# |    episodes         | 324       |
# |    fps              | 2161      |
# |    time_elapsed     | 74        |
# |    total_timesteps  | 162000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.89      |
# |    n_updates        | 27999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.36e+04 |
# |    exploration_rate | 0.688     |
# | time/               |           |
# |    episodes         | 328       |
# |    fps              | 2155      |
# |    time_elapsed     | 76        |
# |    total_timesteps  | 164000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.01      |
# |    n_updates        | 28499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.33e+04 |
# |    exploration_rate | 0.685     |
# | time/               |           |
# |    episodes         | 332       |
# |    fps              | 2150      |
# |    time_elapsed     | 77        |
# |    total_timesteps  | 166000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.41      |
# |    n_updates        | 28999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.32e+04 |
# |    exploration_rate | 0.681     |
# | time/               |           |
# |    episodes         | 336       |
# |    fps              | 2145      |
# |    time_elapsed     | 78        |
# |    total_timesteps  | 168000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.13      |
# |    n_updates        | 29499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.32e+04 |
# |    exploration_rate | 0.677     |
# | time/               |           |
# |    episodes         | 340       |
# |    fps              | 2140      |
# |    time_elapsed     | 79        |
# |    total_timesteps  | 170000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.56      |
# |    n_updates        | 29999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.27e+04 |
# |    exploration_rate | 0.673     |
# | time/               |           |
# |    episodes         | 344       |
# |    fps              | 2135      |
# |    time_elapsed     | 80        |
# |    total_timesteps  | 172000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.4       |
# |    n_updates        | 30499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.26e+04 |
# |    exploration_rate | 0.669     |
# | time/               |           |
# |    episodes         | 348       |
# |    fps              | 2130      |
# |    time_elapsed     | 81        |
# |    total_timesteps  | 174000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.46      |
# |    n_updates        | 30999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.22e+04 |
# |    exploration_rate | 0.666     |
# | time/               |           |
# |    episodes         | 352       |
# |    fps              | 2125      |
# |    time_elapsed     | 82        |
# |    total_timesteps  | 176000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 7.8       |
# |    n_updates        | 31499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.21e+04 |
# |    exploration_rate | 0.662     |
# | time/               |           |
# |    episodes         | 356       |
# |    fps              | 2121      |
# |    time_elapsed     | 83        |
# |    total_timesteps  | 178000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.93      |
# |    n_updates        | 31999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.18e+04 |
# |    exploration_rate | 0.658     |
# | time/               |           |
# |    episodes         | 360       |
# |    fps              | 2116      |
# |    time_elapsed     | 85        |
# |    total_timesteps  | 180000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 7.58      |
# |    n_updates        | 32499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.17e+04 |
# |    exploration_rate | 0.654     |
# | time/               |           |
# |    episodes         | 364       |
# |    fps              | 2112      |
# |    time_elapsed     | 86        |
# |    total_timesteps  | 182000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 13.7      |
# |    n_updates        | 32999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.13e+04 |
# |    exploration_rate | 0.65      |
# | time/               |           |
# |    episodes         | 368       |
# |    fps              | 2108      |
# |    time_elapsed     | 87        |
# |    total_timesteps  | 184000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.49      |
# |    n_updates        | 33499     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.11e+04 |
# |    exploration_rate | 0.647     |
# | time/               |           |
# |    episodes         | 372       |
# |    fps              | 2104      |
# |    time_elapsed     | 88        |
# |    total_timesteps  | 186000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 8.15      |
# |    n_updates        | 33999     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.11e+04 |
# |    exploration_rate | 0.643     |
# | time/               |           |
# |    episodes         | 376       |
# |    fps              | 2100      |
# |    time_elapsed     | 89        |
# |    total_timesteps  | 188000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.791     |
# |    n_updates        | 34499     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -1.1e+04 |
# |    exploration_rate | 0.639    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 2096     |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 190000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.96     |
# |    n_updates        | 34999    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 500       |
# |    ep_rew_mean      | -1.09e+04 |
# |    exploration_rate | 0.635     |
# | time/               |           |
# |    episodes         | 384       |
# |    fps              | 2092      |
# |    time_elapsed     | 91        |
# |    total_timesteps  | 192000    |
# | train/              |           |
# ...
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3748     |
# |    fps              | 1608     |
# |    time_elapsed     | 1164     |
# |    total_timesteps  | 1874000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.767    |
# |    n_updates        | 455999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -669     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3752     |
# |    fps              | 1608     |
# |    time_elapsed     | 1166     |
# |    total_timesteps  | 1876000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.748    |
# |    n_updates        | 456499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -668     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3756     |
# |    fps              | 1608     |
# |    time_elapsed     | 1167     |
# |    total_timesteps  | 1878000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.03     |
# |    n_updates        | 456999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -672     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3760     |
# |    fps              | 1608     |
# |    time_elapsed     | 1168     |
# |    total_timesteps  | 1880000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.88     |
# |    n_updates        | 457499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -672     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3764     |
# |    fps              | 1608     |
# |    time_elapsed     | 1170     |
# |    total_timesteps  | 1882000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.468    |
# |    n_updates        | 457999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -674     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3768     |
# |    fps              | 1608     |
# |    time_elapsed     | 1171     |
# |    total_timesteps  | 1884000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.34     |
# |    n_updates        | 458499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -670     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3772     |
# |    fps              | 1608     |
# |    time_elapsed     | 1172     |
# |    total_timesteps  | 1886000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3      |
# |    n_updates        | 458999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -668     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3776     |
# |    fps              | 1608     |
# |    time_elapsed     | 1173     |
# |    total_timesteps  | 1888000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.98     |
# |    n_updates        | 459499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -669     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3780     |
# |    fps              | 1608     |
# |    time_elapsed     | 1175     |
# |    total_timesteps  | 1890000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.932    |
# |    n_updates        | 459999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -671     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3784     |
# |    fps              | 1608     |
# |    time_elapsed     | 1176     |
# |    total_timesteps  | 1892000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.59     |
# |    n_updates        | 460499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -669     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3788     |
# |    fps              | 1607     |
# |    time_elapsed     | 1177     |
# |    total_timesteps  | 1894000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.794    |
# |    n_updates        | 460999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -672     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3792     |
# |    fps              | 1607     |
# |    time_elapsed     | 1179     |
# |    total_timesteps  | 1896000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.58     |
# |    n_updates        | 461499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -674     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3796     |
# |    fps              | 1607     |
# |    time_elapsed     | 1180     |
# |    total_timesteps  | 1898000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.08     |
# |    n_updates        | 461999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -675     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3800     |
# |    fps              | 1607     |
# |    time_elapsed     | 1181     |
# |    total_timesteps  | 1900000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.17     |
# |    n_updates        | 462499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -677     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3804     |
# |    fps              | 1607     |
# |    time_elapsed     | 1183     |
# |    total_timesteps  | 1902000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.815    |
# |    n_updates        | 462999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -678     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3808     |
# |    fps              | 1607     |
# |    time_elapsed     | 1184     |
# |    total_timesteps  | 1904000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.15     |
# |    n_updates        | 463499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -677     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3812     |
# |    fps              | 1607     |
# |    time_elapsed     | 1185     |
# |    total_timesteps  | 1906000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.672    |
# |    n_updates        | 463999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -676     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3816     |
# |    fps              | 1607     |
# |    time_elapsed     | 1187     |
# |    total_timesteps  | 1908000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.48     |
# |    n_updates        | 464499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -677     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3820     |
# |    fps              | 1607     |
# |    time_elapsed     | 1188     |
# |    total_timesteps  | 1910000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27     |
# |    n_updates        | 464999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -674     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3824     |
# |    fps              | 1607     |
# |    time_elapsed     | 1189     |
# |    total_timesteps  | 1912000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.65     |
# |    n_updates        | 465499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -675     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3828     |
# |    fps              | 1607     |
# |    time_elapsed     | 1190     |
# |    total_timesteps  | 1914000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.664    |
# |    n_updates        | 465999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -673     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3832     |
# |    fps              | 1607     |
# |    time_elapsed     | 1192     |
# |    total_timesteps  | 1916000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.546    |
# |    n_updates        | 466499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -675     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3836     |
# |    fps              | 1606     |
# |    time_elapsed     | 1193     |
# |    total_timesteps  | 1918000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.587    |
# |    n_updates        | 466999   |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 total_timesteps = 5000000
# ----> 2 agent.learn(total_timesteps=total_timesteps)
#       4 # Evaluation (return_episode_rewards=True returns (episode_rewards, episode_lengths))
#       5 episode_rewards, episode_lengths = evaluate_policy(agent, wrapped_env, n_eval_episodes=10, return_episode_rewards=True)
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/stable_baselines3/dqn/dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)    265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/stable_baselines3/common/off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/stable_baselines3/dqn/dqn.py:219, in DQN.train(self, gradient_steps, batch_size)
#     217     loss.backward()
#     218     # Clip gradient norm
# --> 219     th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#     220     self.policy.optimizer.step()
#     222 # Increase update counter
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/torch/nn/utils/clip_grad.py:43, in _no_grad.<locals>._no_grad_wrapper(*args, **kwargs)
#      41 def _no_grad_wrapper(*args, **kwargs):
#      42     with torch.no_grad():
# ---> 43         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/torch/nn/utils/clip_grad.py:231, in clip_grad_norm_(parameters, max_norm, norm_type, error_if_nonfinite, foreach)
#     226         warnings.warn(
#     227             "`parameters` is an empty generator, no gradient clipping will occur.",
#     228             stacklevel=3,
#     229         )
#     230 grads = [p.grad for p in parameters if p.grad is not None]
# --> 231 total_norm = _get_total_norm(grads, norm_type, error_if_nonfinite, foreach)
#     232 _clip_grads_with_norm_(parameters, max_norm, total_norm, foreach)
#     233 return total_norm
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/torch/nn/utils/clip_grad.py:43, in _no_grad.<locals>._no_grad_wrapper(*args, **kwargs)
#      41 def _no_grad_wrapper(*args, **kwargs):
#      42     with torch.no_grad():
# ---> 43         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/env_lift/lib/python3.11/site-packages/torch/nn/utils/clip_grad.py:106, in _get_total_norm(tensors, norm_type, error_if_nonfinite, foreach)
#     101     else:
#     102         norms.extend(
#     103             [torch.linalg.vector_norm(g, norm_type) for g in device_tensors]
#     104         )
# --> 106 total_norm = torch.linalg.vector_norm(
#     107     torch.stack([norm.to(first_device) for norm in norms]), norm_type
#     108 )
#     110 if error_if_nonfinite and torch.logical_or(total_norm.isnan(), total_norm.isinf()):
#     111     raise RuntimeError(
#     112         f"The total norm of order {norm_type} for gradients from "
#     113         "`parameters` is non-finite, so it cannot be clipped. To disable "
#     114         "this error and scale the gradients by the non-finite norm anyway, "
#     115         "set `error_if_nonfinite=False`"
#     116     )
#
# KeyboardInterrupt:

# %% [markdown]
# Visualize RL Policy, trained with AIRL Reward Net:

# %%
render_mode = "human" if os.environ.get('DISPLAY') else "rgb_array"
env = gym.make("seals:seals/CartPole-v0", render_mode=render_mode)

# Gymnasium returns (obs, info) from reset(); unpack so `obs` is the raw observation
obs, info = env.reset()

for _ in range(1000):
    # Pass only the observation (not the (obs, info) tuple) to the SB3 policy
    action, _ = agent.predict(obs, deterministic=True)

    # Gymnasium step returns (obs, reward, terminated, truncated, info)
    obs, rew, terminated, truncated, info = env.step(action)

    # Render depending on mode. For `rgb_array` we collect and display frames inside the notebook.
    if render_mode == "rgb_array":
        frame = env.render()
        # display every 10 frames to avoid excessive output
        if (_ % 10) == 0:
            clear_output(wait=True)
            plt.imshow(frame)
            plt.axis('off')
            display(plt.gcf())
    else:
        env.render()   # opens a window (when DISPLAY is available)

    # episode end when either terminated or truncated
    if terminated or truncated:
        obs, info = env.reset()
        # if running in rgb_array mode, break after one episode to show the frames
        if render_mode == "rgb_array":
            break

env.close()
